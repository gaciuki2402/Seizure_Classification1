# %% [markdown]
# <a href="https://colab.research.google.com/github/gaciuki2402/Seizure_Classification1/blob/main/converting_csv_to_edf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importing dependancies
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.svm import  SVC
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# loading csv file
csv_file_path = "/content/drive/MyDrive/CSV/Epileptic Seizure Recognition.csv"
# loading the data to a dataframe
dataframe = pd.read_csv(csv_file_path)

# %%
# printing the first five rows of the dataframe
dataframe.head()
# Out:
#       Unnamed   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
# loading the last five rows of the dataframe
dataframe.tail()
# Out:
#           Unnamed  X1  X2  X3  X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 11495  X22.V1.114 -22 -22 -23 -26  -36  -42  -45  -42  -45  ...    15    16
# 11496  X19.V1.354 -47 -11  28  77  141  211  246  240  193  ...   -65   -33
# 11497    X8.V1.28  14   6 -13 -16   10   26   27   -9    4  ...   -65   -48
# 11498  X10.V1.932 -40 -25  -9 -12   -2   12    7   19   22  ...   121   135
# 11499  X16.V1.210  29  41  57  72   74   62   54   43   31  ...   -59   -25
#
#        X172  X173  X174  X175  X176  X177  X178  y
# 11495    12     5    -1   -18   -37   -47   -48  2
# 11496    -7    14    27    48    77   117   170  1
# 11497   -61   -62   -67   -30    -2    -1    -8  5
# 11498   148   143   116    86    68    59    55  3
# 11499    -4     2     5     4    -2     2    20  4
#
# [5 rows x 180 columns]

# %%
# number of rows and the columns
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
# checking for any missing values
dataframe.isnull().sum()
# Out:
# Unnamed    0
# X1         0
# X2         0
# X3         0
# X4         0
#           ..
# X175       0
# X176       0
# X177       0
# X178       0
# y          0
# Length: 180, dtype: int64

# %%
dataframe.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
# checking the distribution of targets
print("Only subjetcts in class 1 have epilectic seizure")
dataframe['y'].value_counts()
# Out:
# Only subjetcts in class 1 have epilectic seizure
# 4    2300
# 1    2300
# 5    2300
# 2    2300
# 3    2300
# Name: y, dtype: int64

# %%
dic = {5:0, 4:0, 3:0, 2:0, 1:1}
dataframe['y'] = dataframe['y'].map(dic)

non_seizure, seizure = dataframe['y'].value_counts()
print(f"The number of trials for non-seizure class: {non_seizure}")
print(f"The number of trials for seizure class: {seizure}")
# Out:
# The number of trials for non-seizure class: 9200
# The number of trials for seizure class: 2300

# %%
# dropping unnecessary fearures
dataframe = dataframe.drop('Unnamed', axis = 1)

# %%
dataframe.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232  ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64    48
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81   -80
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2   -12
#
#    X173  X174  X175  X176  X177  X178  y
# 0   -77  -103  -127  -116   -83   -51  0
# 1   152   157   156   154   143   129  1
# 2    19   -12   -30   -35   -35   -36  0
# 3   -77   -85   -77   -72   -69   -65  0
# 4   -32   -41   -65   -83   -89   -73  0
#
# [5 rows x 179 columns]

# %%
dataframe.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 179 entries, X1 to y
# dtypes: int64(179)
# memory usage: 15.7 MB

# %%
# extracting the features
X = dataframe.drop('y', axis=1)
Y = dataframe['y']

# %%
print(Y)
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 11495    0
# 11496    1
# 11497    0
# 11498    0
# 11499    0
# Name: y, Length: 11500, dtype: int64

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
print(X_scaled)

# %%
# split the data into training and test data
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size=0.2, random_state= 42)

# %%
# initialize SVM classifier with a radial basos function(RBF) kernel
svm_classifier = SVC(kernel='rbf', C=1.0, gamma='scale')

# %%
# train the SVM classifier
svm_classifier.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-5b3f05756cbc> in <cell line: 2>()
#       1 # train the SVM classifier
# ----> 2 svm_classifier.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined
